# %% [markdown]
# ## Build the Bronze Layer Transformation for Orders

# %%
from pyspark.sql.types import StructType, StructField, StringType
from pyspark.sql.functions import current_timestamp

# 1. Define Bronze Schema (keeping raw dates as StringType to prevent load nulls)
olist_orders_schema = StructType([
    StructField("order_id", StringType(), True),
    StructField("customer_id", StringType(), True),
    StructField("order_status", StringType(), True),
    StructField("order_purchase_timestamp", StringType(), True),
    StructField("order_approved_at", StringType(), True),
    StructField("order_delivered_carrier_date", StringType(), True),
    StructField("order_delivered_customer_date", StringType(), True),
    StructField("order_estimated_delivery_date", StringType(), True)
])

# 2. Read Raw CSV file
olist_orders_df =(
    spark.read.csv("/Volumes/upskill/pyspark_learning/datasets/Brazilian_ECommerce_Dataset/olist_orders_dataset.csv",header=True,schema=olist_orders_schema)
)

# 3. Add Ingestion Metadata (Reassigning variable)
olist_orders_df = olist_orders_df.withColumn("ingested_at",current_timestamp())

# 4. Save to Bronze Delta Table
olist_orders_df.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("upskill.pyspark_learning.bronze_olist_orders")


display(spark.sql("SELECT * FROM upskill.pyspark_learning.bronze_olist_orders LIMIT 5"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ## Ingest & Clean the Order Payments

# %%
from pyspark.sql.types import StructType, StructField, StringType,IntegerType,DoubleType
from pyspark.sql.functions import current_timestamp


# 1. Define Bronze Schema (keeping raw dates as StringType to prevent load nulls)
olist_orderPayment_schema = StructType([
    StructField("order_id", StringType(), True),
    StructField("payment_sequential", IntegerType(), True),
    StructField("payment_type", StringType(), True),
    StructField("payment_installments", IntegerType(), True),
    StructField("payment_value", DoubleType(), True)
])

# 2. Read Raw CSV file
olist_orderPayment_df = spark.read \
    .option("header", "true") \
    .schema(olist_orderPayment_schema) \
    .csv("/Volumes/upskill/pyspark_learning/datasets/Brazilian_ECommerce_Dataset/olist_order_payments_dataset.csv")

# 3. Add Ingestion Metadata (Reassigning variable)
olist_orderPayment_df = olist_orderPayment_df.withColumn("ingested_at",current_timestamp())

# 4. Save to Bronze Delta Table
olist_orderPayment_df.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("upskill.pyspark_learning.bronze_olist_orderPayment")


display(spark.sql("SELECT * FROM upskill.pyspark_learning.bronze_olist_orderPayment LIMIT 5"))

# %% [markdown]
# ## Build the Bronze Layer Transformation for customer dataset

# %%
from pyspark.sql.types import StructType, StructField, StringType,IntegerType,DoubleType
from pyspark.sql.functions import current_timestamp


# 1. Define Bronze Schema (keeping raw dates as StringType to prevent load nulls)
olist_customer_schema = StructType([
    StructField("customer_id", StringType(), True),
    StructField("customer_unique_id", StringType(), True),
    StructField("customer_zip_code_prefix", StringType(), True),
    StructField("customer_city", StringType(), True),
    StructField("customer_state", StringType(), True)
])

# 2. Read Raw CSV file
olist_customer_df = spark.read \
    .option("header", "true") \
    .schema(olist_customer_schema) \
    .csv("/Volumes/upskill/pyspark_learning/datasets/Brazilian_ECommerce_Dataset/olist_customers_dataset.csv")

# 3. Add Ingestion Metadata (Reassigning variable)
olist_customer_df = olist_customer_df.withColumn("ingested_at",current_timestamp())

# 4. Save to Bronze Delta Table
olist_customer_df.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("upskill.pyspark_learning.bronze_olist_customer")


display(spark.sql("SELECT * FROM upskill.pyspark_learning.bronze_olist_customer LIMIT 5"))

# %% [markdown]
# ## Build the Bronze Layer Transformation for product dataset

# %%
from pyspark.sql.types import StructType, StructField, StringType,IntegerType
from pyspark.sql.functions import current_timestamp

# 1. Define Bronze Schema (keeping raw dates as StringType to prevent load nulls)
olist_products_schema = StructType([
    StructField("product_id", StringType(), True),
    StructField("product_category_name", StringType(), True),
    StructField("product_name_lenght", IntegerType(), True),
    StructField("product_description_lenght", IntegerType(), True),
    StructField("product_photos_qty", IntegerType(), True),
    StructField("product_weight_g", IntegerType(), True),
    StructField("product_length_cm", IntegerType(), True),
    StructField("product_height_cm", IntegerType(), True),
    StructField("product_width_cm", IntegerType(), True)
])

# 2. Read Raw CSV file
olist_products_df = spark.read \
    .option("header", "true") \
    .schema(olist_products_schema) \
    .csv("/Volumes/upskill/pyspark_learning/datasets/Brazilian_ECommerce_Dataset/olist_products_dataset.csv")

# 3. Add Ingestion Metadata (Reassigning variable)
olist_products_df = olist_products_df.withColumn("ingested_at",current_timestamp())

# 4. Save to Bronze Delta Table
olist_products_df.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("upskill.pyspark_learning.bronze_olist_products")


display(spark.sql("SELECT * FROM upskill.pyspark_learning.bronze_olist_products LIMIT 5"))

# %% [markdown]
# ## Build the Bronze Layer Transformation for product category dataset

# %%
from pyspark.sql.types import StructType, StructField, StringType,IntegerType,DoubleType
from pyspark.sql.functions import current_timestamp
,

# 1. Define Bronze Schema (keeping raw dates as StringType to prevent load nulls)
olist_product_category_schema = StructType([
    StructField("product_category_name", StringType(), True),
    StructField("product_category_name_english", StringType(), True)
])

# 2. Read Raw CSV file
olist_product_category_df = spark.read \
    .option("header", "true") \
    .schema(olist_product_category_schema) \
    .csv("/Volumes/upskill/pyspark_learning/datasets/Brazilian_ECommerce_Dataset/product_category_name_translation.csv")

# 3. Add Ingestion Metadata (Reassigning variable)
olist_product_category_df = olist_product_category_df.withColumn("ingested_at",current_timestamp())

# 4. Save to Bronze Delta Table
olist_product_category_df.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("upskill.pyspark_learning.bronze_olist_product_category")


display(spark.sql("SELECT * FROM upskill.pyspark_learning.bronze_olist_product_category LIMIT 5"))

# %% [markdown]
# ## Build the Bronze Layer Transformation for order items dataset

# %%
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, DoubleType, TimestampType
from pyspark.sql.functions import current_timestamp, col, to_timestamp

# ==========================================
# 1. BRONZE LAYER: Raw CSV Ingestion
# ==========================================

# Define Bronze Schema (keep date as StringType during raw read)
order_items_schema = StructType([
    StructField("order_id", StringType(), True),
    StructField("order_item_id", IntegerType(), True),
    StructField("product_id", StringType(), True),
    StructField("seller_id", StringType(), True),
    StructField("shipping_limit_date", StringType(), True),
    StructField("price", DoubleType(), True),
    StructField("freight_value", DoubleType(), True)
])

# Read Raw CSV File
bronze_order_items_df = spark.read \
    .option("header", "true") \
    .schema(order_items_schema) \
    .csv("/Volumes/upskill/pyspark_learning/datasets/Brazilian_ECommerce_Dataset/olist_order_items_dataset.csv")
    
# Add Ingestion Metadata
bronze_order_items_df = bronze_order_items_df.withColumn("_ingested_at", current_timestamp())

# Save to Bronze Delta Table
bronze_order_items_df.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("upskill.pyspark_learning.bronze_olist_order_items")
